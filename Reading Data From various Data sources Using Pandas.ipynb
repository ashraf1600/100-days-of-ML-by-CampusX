# %%
import pandas as pd
from io import StringIO
Data = [
  {
    "id": 1,
    "name": "Alice Johnson",
    "email": "alice.johnson@example.com",
    "age": 29,
    "is_active": true,
    "signup_date": "2023-03-15",
    "preferences": {
      "newsletter": true,
      "notifications": "daily"
    }
  },
  {
    "id": 2,
    "name": "Bob Smith",
    "email": "bob.smith@example.com",
    "age": 34,
    "is_active": false,
    "signup_date": "2022-11-08",
    "preferences": {
      "newsletter": false,
      "notifications": "weekly"
    }
  },
  {
    "id": 3,
    "name": "Clara Lee",
    "email": "clara.lee@example.com",
    "age": 24,
    "is_active": true,
    "signup_date": "2024-01-21",
    "preferences": {
      "newsletter": true,
      "notifications": "none"
    }
  }
]
pd.read_json(Data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       1 import pandas as pd
#       2 from io import StringIO
#       3 Data = [
#       4   {
#       5     "id": 1,
#       6     "name": "Alice Johnson",
#       7     "email": "alice.johnson@example.com",
#       8     "age": 29,
# ----> 9     "is_active": true,
#      10     "signup_date": "2023-03-15",
#      11     "preferences": {
#      12       "newsletter": true,
#      13       "notifications": "daily"
#      14     }
#      15   },
#      16   {
#      17     "id": 2,
#      18     "name": "Bob Smith",
#      19     "email": "bob.smith@example.com",
#      20     "age": 34,
#      21     "is_active": false,
#      22     "signup_date": "2022-11-08",
#      23     "preferences": {
#      24       "newsletter": false,
#      25       "notifications": "weekly"
#      26     }
#      27   },
# ...

# %%
'''
❌ Problem:
You're passing a Python list of dictionaries (Data) directly to pd.read_json().
However, pd.read_json() expects:

1. A JSON string

2. A file path

3. Or a file-like object

'''

# %%
import pandas as pd
from io import StringIO
Data = [
  {
    "id": 1,
    "name": "Alice Johnson",
    "email": "alice.johnson@example.com",
    "age": 29,
    "is_active": True,
    "signup_date": "2023-03-15",
    "preferences": {
      "newsletter": True,
      "notifications": "daily"
    }
  },
  {
    "id": 2,
    "name": "Bob Smith",
    "email": "bob.smith@example.com",
    "age": 34,
    "is_active": False,
    "signup_date": "2022-11-08",
    "preferences": {
      "newsletter": False,
      "notifications": "weekly"
    }
  },
  {
    "id": 3,
    "name": "Clara Lee",
    "email": "clara.lee@example.com",
    "age": 24,
    "is_active": True,
    "signup_date": "2024-01-21",
    "preferences": {
      "newsletter": True,
      "notifications": "none"
    }
  }
]
df = pd.DataFrame(Data)
df
# Out:
#    id           name                      email  age  is_active signup_date  \
# 0   1  Alice Johnson  alice.johnson@example.com   29       True  2023-03-15
# 1   2      Bob Smith      bob.smith@example.com   34      False  2022-11-08
# 2   3      Clara Lee      clara.lee@example.com   24       True  2024-01-21
#
#                                         preferences
# 0    {'newsletter': True, 'notifications': 'daily'}
# 1  {'newsletter': False, 'notifications': 'weekly'}
# 2     {'newsletter': True, 'notifications': 'none'}

# %%
df.to_json(orient='records')
# Out:
# '[{"id":1,"name":"Alice Johnson","email":"alice.johnson@example.com","age":29,"is_active":true,"signup_date":"2023-03-15","preferences":{"newsletter":true,"notifications":"daily"}},{"id":2,"name":"Bob Smith","email":"bob.smith@example.com","age":34,"is_active":false,"signup_date":"2022-11-08","preferences":{"newsletter":false,"notifications":"weekly"}},{"id":3,"name":"Clara Lee","email":"clara.lee@example.com","age":24,"is_active":true,"signup_date":"2024-01-21","preferences":{"newsletter":true,"notifications":"none"}}]'

# %%
df = pd.read_csv('wine.data')
df.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
df.to_csv('wine.csv')

# %%
## we can read data giving  a url from browser just html json etc data can be gievn
